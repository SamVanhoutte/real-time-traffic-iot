# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from datetime import datetime, timedelta
import json
import pyspark.sql.functions
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Load variables from key vault

# %%
kv_scope = 'key-vault-secret'

# Variables
storage_account_name = dbutils.secrets.get(scope=kv_scope, key='traffic-storage-accountname') 
storage_account_access_key = dbutils.secrets.get(scope=kv_scope, key='traffic-storage-accountkey') 
eventgrid_accesskey = dbutils.secrets.get(scope=kv_scope, key='traffic-eventgrid-accesskey') 
eventgrid_topic = dbutils.secrets.get(scope=kv_scope, key='traffic-eventgrid-topicendpoint')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
traffic_table_name = 'CameraTelemetry' + datetime.today().strftime('%Y%m%d')
speed_table_name = 'SpeedMeasurements' + datetime.today().strftime('%Y%m%d')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Mounting the segment configuration json from blob
#
# - Using the mount functionality to load the blob file

# %%
mount_name = 'traffic-config'
to_be_mounted = True
mounts = dbutils.fs.ls('/mnt/')

for mnt in mounts:
  if mnt.name.startswith(mount_name):
    to_be_mounted = False

if to_be_mounted:
  dbutils.fs.mount(
  source = 'wasbs://traffic-config@' + storage_account_name + '.blob.core.windows.net',
  mount_point = '/mnt/' + mount_name,
  extra_configs = {'fs.azure.account.key.' + storage_account_name + '.blob.core.windows.net':storage_account_access_key})
else:
  print('Traffic config already mounted')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Traffic config already mounted
# </div>

# %% [markdown]
# ## Parsing segment configuration
#
# - Reading the json file (`multiLine=True` !!)
# - Adding calculated field for maximum duration (`(distance / speedlimit) * 3.6`), where 3.6 is coming from meters/second
# - Only returning the relevant fields for the calculation query

# %%
segment_config = spark.read.json('/mnt/' + mount_name, multiLine=True) \
  .withColumn('TrajectId', col('segmentId')) \
  .withColumn('MinDuration', ((col('cameraDistance') / col('speedLimit')) * 3.6)) \
  .select('TrajectId','MinDuration', 'CameraDistance', 'SpeedLimit')
display(segment_config)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TrajectId</th><th>MinDuration</th><th>CameraDistance</th><th>SpeedLimit</th></tr></thead><tbody><tr><td>dev</td><td>80.0</td><td>2000</td><td>90</td></tr><tr><td>edge01</td><td>80.0</td><td>2000</td><td>90</td></tr><tr><td>01</td><td>80.0</td><td>2000</td><td>90</td></tr><tr><td>02</td><td>150.0</td><td>5000</td><td>120</td></tr><tr><td>03</td><td>261.81818181818187</td><td>8000</td><td>110</td></tr><tr><td>04</td><td>49.09090909090909</td><td>1500</td><td>110</td></tr></tbody></table></div>

# %%
timestamp_from = datetime.utcnow() - timedelta(hours=0, minutes=20)
print(timestamp_from)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2020-05-27 07:54:23.686048
# </div>

# %%
cameraStream = spark.readStream.format('delta') \
  .table(traffic_table_name) \
  .where(col('EventTime')>'2019-12-12 18:30:00')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Query that shows traffic (car count) per 5 second window

# %%
import pyspark.sql.functions as F

traffic_df = cameraStream \
  .where(col('EventTime') > timestamp_from) \
  .groupBy(window('EventTime', '30 seconds')) \
  .agg(count('*').alias('count')) \
  .select(col('window.start').alias('start'), 'count')

display(traffic_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
# %% [markdown]
# ## Query that shows number of cars per segment

# %%
segment_df = cameraStream \
  .groupBy('TrajectId', window('EventTime', '60 seconds')) \
  .agg(count('*').alias('count')) \
  .sort(col('count').desc()) \
  .select('TrajectId', col('window.start').alias('WindowTime'), 'count')

display(segment_df)

# %% [markdown]
# ## Query that shows the number of cars, grouped by country

# %%
import pyspark.sql.functions as F

country_df = cameraStream \
  .groupBy('Country') \
  .agg(count('*').alias('count')) \
  .sort(F.col('count').desc()) \
  .select('Country', 'count')

display(country_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Country</th><th>count</th></tr></thead><tbody><tr><td>BE</td><td>508</td></tr><tr><td>NL</td><td>47</td></tr><tr><td>DE</td><td>45</td></tr><tr><td>FR</td><td>32</td></tr><tr><td>PL</td><td>28</td></tr><tr><td>HU</td><td>8</td></tr><tr><td>PT</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Speed measurements & reports

# %%
speedMeasurementStream = spark.readStream.option('ignoreChanges', 'true').table(speed_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
t02 = speedMeasurementStream.where(col('LastEvent')>'2020-05-26 19:20:00') 
display(t02)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TrajectId</th><th>LicensePlate</th><th>Speed</th><th>Make</th><th>Country</th><th>LastEvent</th><th>SpeedLimit</th><th>Duration</th></tr></thead><tbody><tr><td>01</td><td>1-AGI-045</td><td>135.8490566037736</td><td>Mercedes</td><td>BE</td><td>2020-05-27T08:11:45.131+0000</td><td>90</td><td>53</td></tr><tr><td>04</td><td>1-ARM-623</td><td>83.07692307692308</td><td>Suzuki</td><td>BE</td><td>2020-05-27T08:11:52.189+0000</td><td>110</td><td>65</td></tr><tr><td>04</td><td>1-WVT-015</td><td>85.71428571428572</td><td>Volvo</td><td>PL</td><td>2020-05-27T08:11:45.967+0000</td><td>110</td><td>63</td></tr><tr><td>01</td><td>1-FOT-659</td><td>120.00000000000001</td><td>Audi</td><td>BE</td><td>2020-05-27T08:11:55.415+0000</td><td>90</td><td>60</td></tr><tr><td>01</td><td>1-DBO-791</td><td>122.03389830508476</td><td>Saab</td><td>FR</td><td>2020-05-27T08:11:39.176+0000</td><td>90</td><td>59</td></tr><tr><td>01</td><td>1-UBR-317</td><td>116.12903225806451</td><td>Saab</td><td>BE</td><td>2020-05-27T08:11:50.353+0000</td><td>90</td><td>62</td></tr><tr><td>04</td><td>1-DRF-450</td><td>85.71428571428572</td><td>BMW</td><td>BE</td><td>2020-05-27T08:11:55.309+0000</td><td>110</td><td>63</td></tr><tr><td>01</td><td>1-TEZ-181</td><td>120.00000000000001</td><td>Volkswagen</td><td>BE</td><td>2020-05-27T08:11:46.484+0000</td><td>90</td><td>60</td></tr><tr><td>01</td><td>1-EJV-625</td><td>124.13793103448278</td><td>Renault</td><td>DE</td><td>2020-05-27T08:12:01.728